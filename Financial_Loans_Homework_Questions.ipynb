# %% [markdown]
# # Financial Loans & Credit Risk Investigation
#
# **Role:** Junior Data Analyst at a lending company
#
# Management believes loan volumes are growing, but is concerned that some growth may be coming from increasingly risky customers. You have been given transaction-linked customer, bureau and loan-performance data.
#
# This is deliberately imperfect data. Your job is not to copy syntax: **decide what to calculate, choose the right level of analysis, validate your joins, handle missing values thoughtfully, and explain what the numbers mean.**
#
# **Rules:** State assumptions when thresholds are not provided. Use loan/customer-level denominators when appropriate. Avoid causal claims from descriptive data.

# %% [markdown]
# ## Data dictionary
#
# | Field | Meaning |
# |---|---|
# | `transaction_id` | Unique transaction ID |
# | `transaction_date` | Transaction date |
# | `customer_id` | Customer ID |
# | `loan_id` | Loan linked to the customer |
# | `age`, `gender`, `city`, `state` | Demographics |
# | `employment_type`, `customer_segment` | Customer classification |
# | `monthly_income` | Monthly income (INR) |
# | `credit_score` | Bureau credit score |
# | `bureau_accounts`, `active_accounts`, `overdue_accounts` | Bureau account indicators |
# | `total_bureau_loan_amount` | Bureau-reported loan exposure |
# | `credit_utilization` | Credit utilization ratio |
# | `loan_type`, `loan_amount`, `tenure_months`, `interest_rate` | Loan characteristics |
# | `loan_status` | Active / Closed / Delinquent / Default / Written Off |
# | `disbursement_date`, `emi_amount` | Loan timing and EMI |
# | `days_past_due`, `emi_paid`, `emi_missed`, `late_payment_count` | Repayment behaviour |
# | `principal_outstanding`, `interest_paid`, `penalty_amount`, `recovery_amount`, `profit_amount` | Loan performance / financial outcomes |
# | `transaction_type`, `transaction_amount` | Transaction details |
# | `payment_channel`, `merchant_category`, `transaction_status` | Transaction attributes |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset here

# %% [markdown]
# ## 1. Data grain & quality
#
# **Q1.** Load the CSV and determine what one row represents. What evidence supports your conclusion?
#
# **Q2.** Check shape, types and unique counts for customers, loans and transactions. Which IDs are true keys at this file's grain?
#
# **Q3.** Find duplicate values for each ID. Which duplicates are expected because of the data grain?
#
# **Q4.** Profile missing values. Which missing fields could materially change a credit-risk conclusion?
#
# **Q5.** Identify at least two numerical columns where outliers may make the mean misleading. Compare mean vs median.

# %%
# Write your code for this section here

# %% [markdown]
# ## 2. Investigation & derived metrics
#
# **Q6.** Calculate the default/write-off rate using the correct denominator. Explain why counting raw rows could be wrong.
#
# **Q7.** Create `loan_to_income_ratio`. Find unusually stretched loans. Choose and justify a threshold.
#
# **Q8.** Create `outstanding_ratio = principal_outstanding / loan_amount`. What share of loans has more than 80% still outstanding?
#
# **Q9.** Create a `problem_loan` flag using either bad status or at least 3 missed EMIs. Compare its rate across loan types.
#
# **Q10.** Create a sensible `profit_margin`. Find the 10 weakest loans and investigate their loan types/statuses.
#
# **Q11.** Find customers who look low-risk by credit score but have poor repayment behaviour. How many distinct customers are there?
#
# **Q12.** Find high-income customers with high credit utilization. Define “high” and defend your choice.

# %%
# Write your code for this section here

# %% [markdown]
# ## 3. Filtering & tricky logic
#
# **Q13.** Find loans with low credit score AND high loan amount. Then find loans with low credit score OR high utilization. Compare the populations.
#
# **Q14.** Find transactions that are either unusually large OR unsuccessful. Report counts without double-counting.
#
# **Q15.** Find defaulted/written-off loans where the customer nevertheless has a credit score of at least 750. What does this exception suggest?
#
# **Q16.** Find high-value loans with negative profit. Which loan types are over-represented?
#
# **Q17.** Identify customers with many transactions but poor repayment. Decide what “many” means and explain.

# %%
# Write your code for this section here

# %% [markdown]
# ## 4. Grouping & business metrics
#
# **Q18.** For each state calculate loan count, total loan amount, total outstanding, total profit and default rate. Which state looks strongest overall?
#
# **Q19.** For each loan type calculate volume, average loan, average interest rate, total profit and default rate. Which type is profitable but risky?
#
# **Q20.** Compare customer segments on average income, average loan amount, average missed EMIs and default rate.
#
# **Q21.** Compare employment types using average credit score, average utilization and average missed EMIs.
#
# **Q22.** Calculate each loan type's share of total profit. How does this ranking differ from total loan volume?
#
# **Q23.** Identify the state with the highest default rate. Does it remain the highest after requiring at least 50 loans?
#
# **Q24.** For each state and loan type, calculate default rate and loan count. Identify high-risk combinations with enough observations.

# %%
# Write your code for this section here

# %% [markdown]
# ## 5. JOINs & avoiding double counting
#
# **Q25.** Build a unique `customers` table from the raw data. Verify `customer_id` is unique.
#
# **Q26.** Build a unique `loans` table. Verify `loan_id` is unique.
#
# **Q27.** Build a transaction table containing transaction-level fields. Explain its grain.
#
# **Q28.** Merge loans with customers. Compare row counts before and after. Why should the loan count stay stable?
#
# **Q29.** Aggregate transactions to customer level (count, total amount, successful transaction count) and then join the summary to loans. Why is this safer than directly attaching every transaction row to every loan?
#
# **Q30.** Find loans belonging to customers with zero successful transactions.
#
# **Q31.** After joining, check whether any metric has been accidentally duplicated. Demonstrate one validation check.
#
# **Q32.** Find customers with high transaction activity and at least 3 missed EMIs, then compare their average credit score with the rest.

# %%
# Write your code for this section here

# %% [markdown]
# ## 6. Pivot tables
#
# **Q33.** Build a pivot showing total loan amount by state and loan type. Identify concentration rather than simply reporting the table.
#
# **Q34.** Build a pivot of default rate by customer segment and loan type. Which cells deserve investigation?
#
# **Q35.** Build a monthly pivot of loan amount and profit by loan type. Identify a type where volume and profit do not move together.
#
# **Q36.** Build a pivot comparing average credit score and days past due by customer segment and loan status. What pattern stands out?

# %%
# Write your code for this section here

# %% [markdown]
# ## 7. NumPy + Pandas
#
# **Q37.** Convert non-missing loan amounts to a NumPy array and verify its mean and median against Pandas.
#
# **Q38.** Use a NumPy boolean mask to count loans above the median loan amount.
#
# **Q39.** Create a three-level risk label with `np.where()` from credit score, then compare labels with actual bad-loan outcomes.
#
# **Q40.** At customer level, compare total outstanding with monthly income using NumPy. Identify the customers with the largest gap.

# %%
# Write your code for this section here

# %% [markdown]
# ## 8. Missing values
#
# **Q41.** Calculate missing percentages. Which missingness should be preserved rather than blindly imputed?
#
# **Q42.** Compare the mean of income before and after median imputation. Did the distribution materially change?
#
# **Q43.** Compare default rate when missing credit scores are excluded versus when they are filled using a simple rule. Discuss the limitation.
#
# **Q44.** Investigate whether customers with missing employment information have noticeably different loan outcomes. Do not assume missingness is random.

# %%
# Write your code for this section here

# %% [markdown]
# ## 9. Visualization
#
# **Q45.** Create a **bar chart** comparing total profit by loan type. Add title and axis labels and state the business takeaway.
#
# **Q46.** Create a **line chart** of monthly loan amount and monthly profit. Does growth in lending translate into profit growth?
#
# **Q47.** Create a **scatter plot** of credit score vs loan amount, distinguishing loan status where useful. Describe the relationship and exceptions.
#
# **Q48.** Create a **scatter plot** of credit utilization vs principal outstanding. What does the chart suggest?
#
# **Q49.** Management asks whether larger loans are better business. Choose the most appropriate chart, create it, and explain why you chose it.

# %%
# Write your code for this section here

# %% [markdown]
# ## 10. Integrated challenges
#
# **Q50.** A manager says: “The state with the highest default rate is our worst market.” Test this claim using rate, volume, outstanding exposure and credit score.
#
# **Q51.** Determine whether higher interest rates appear to compensate for higher risk. Compare interest rate, default rate and profit across sensible bands.
#
# **Q52.** Compare the top 10% largest loans with the remaining 90% on default rate, credit score, missed EMIs and profit margin.
#
# **Q53.** Find one conclusion that changes materially when you use median instead of mean.
#
# **Q54.** Find one relationship that looks different after splitting the data by customer segment or loan type. Explain what changed.

# %%
# Write your code for this section here

# %% [markdown]
# ## 11. CEO Case Study
#
# **Q55. CEO challenge**
#
# > “Loan volumes are growing, but I'm worried that we may be taking on more risk than we realise. I don't want another dashboard. I want to know what the data is actually telling us.”
#
# Prepare a concise analytical response.
#
# Address:
# 1. Is loan growth accompanied by profit growth?
# 2. Which loan types are most profitable and which are riskiest?
# 3. Which customer segments require attention?
# 4. How useful is credit score for identifying repayment risk here?
# 5. Does larger loan size appear associated with higher risk?
# 6. Does higher interest rate compensate for higher risk?
# 7. What role does credit utilization appear to play?
# 8. What is one surprising finding?
# 9. What should management investigate next?
#
# Support the response with calculations and **at least 3 visualizations: bar, line and scatter**.
#
# Finish with a **7–10 sentence executive summary containing at least 5 numerical findings**.

# %%
# Write your code for this section here
