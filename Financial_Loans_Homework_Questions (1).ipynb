# %% [markdown]
# # Financial Loans & Credit Risk Investigation
#
# You are a junior data analyst at a lending company. Five related datasets contain customer demographics, bureau data, loans, repayments and transactions.
#
# **This is intentionally not a syntax copy-paste assignment.** You must determine the correct grain, choose denominators, validate joins, handle missing values and explain business meaning.

# %% [markdown]
# ## Files
# `customers.csv` · `bureau.csv` · `loans.csv` · `repayments.csv` · `transactions.csv`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the five files here

# %% [markdown]
# ## Data grain & quality
#
# Q1. Load all five files and report their shapes. What does one row represent in each?
#
# Q2. Verify the candidate primary key of every table. Which IDs repeat and why?
#
# Q3. Profile missing values. Which missing fields could materially bias a risk analysis?
#
# Q4. Find customers present in customers.csv but absent from bureau.csv. Explain your join choice.

# %%
# Write your code here

# %% [markdown]
# ## Loan & repayment analysis
#
# Q5. Compare mean and median loan amount. What does the difference suggest?
#
# Q6. Join income to loans and create loan-to-income ratio. Define and justify a threshold for stretched loans.
#
# Q7. Calculate default/write-off rate by loan type using the correct denominator.
#
# Q8. Aggregate repayments to loan level: total paid, missed installments and maximum DPD.
#
# Q9. Find serious delinquency among loans not currently marked Default/Written Off.
#
# Q10. Compare loan outcomes for zero missed installments versus 3+ missed installments.

# %%
# Write your code here

# %% [markdown]
# ## Transactions & joins
#
# Q11. Aggregate transactions to customer level: count, total value, successful count and failed/reversed count.
#
# Q12. Which payment channel has the weakest transaction success rate?
#
# Q13. Identify customers with unusually high transaction activity and poor repayment. Define unusually high.
#
# Q14. Merge loans with customers and bureau. Validate row counts before/after.
#
# Q15. Compare customers→loans using left vs inner join. Who disappears?
#
# Q16. Join loans directly to repayments. Explain the row-count increase.
#
# Q17. Demonstrate how summing loan amount after that join can overstate exposure.
#
# Q18. Aggregate repayments first, then join. Explain why this is safer.
#
# Q19. Use merge indicators to identify unmatched records.

# %%
# Write your code here

# %% [markdown]
# ## Grouping & pivots
#
# Q20. For each state calculate loan count, total exposure, average loan and default rate. Which state looks strongest depends on the metric?
#
# Q21. For each loan type calculate volume, average amount, average rate, exposure and default rate.
#
# Q22. Calculate state × loan type default rates. Ignore groups with fewer than 30 loans.
#
# Q23. Create a state × loan type pivot of total exposure. Interpret concentration.
#
# Q24. Create a segment × loan type pivot of default rate. Identify cells worth investigating.
#
# Q25. Create a monthly pivot of loan volume by loan type. What changes over time?

# %%
# Write your code here

# %% [markdown]
# ## Missing values & NumPy
#
# Q26. Compare default rates for customers with and without a bureau credit score. Why might missingness matter?
#
# Q27. Compare mean income before and after median imputation. Should you impute it?
#
# Q28. Use NumPy to calculate mean/median loan amount and validate against Pandas.
#
# Q29. Use a NumPy mask for loans above the 90th percentile and compare risk with the rest.
#
# Q30. Use np.where to create a three-level credit-risk band and compare it with outcomes.

# %%
# Write your code here

# %% [markdown]
# ## Visualization
#
# Q31. Create a bar chart of total loan exposure by loan type. State the takeaway.
#
# Q32. Create a line chart of monthly loan disbursement. Describe the trend.
#
# Q33. Create a scatter plot of credit score vs loan amount, distinguishing loan status where useful.
#
# Q34. Create a scatter plot of credit utilization vs loan amount/outstanding exposure. Interpret cautiously.
#
# Q35. Management asks whether bigger loans are better business. Choose an appropriate chart and justify it.

# %%
# Write your code here

# %% [markdown]
# ## Integrated challenges
#
# Q36. A manager says the state with the highest default rate is the worst market. Test the claim using rate, volume, exposure and credit score.
#
# Q37. Investigate whether higher interest rates appear to compensate for higher risk.
#
# Q38. Compare the top 10% largest loans with the remaining 90% on risk indicators.
#
# Q39. Find one conclusion that changes materially when using median instead of mean.
#
# Q40. Find one relationship that changes after splitting by customer segment or loan type. Explain.

# %%
# Write your code here

# %% [markdown]
# ## CEO case study
#
# Q41. CEO: “Loan volumes are growing, but I’m worried we may be taking on more risk than we realise.” Produce a 7–10 sentence executive response covering growth vs profitability, riskiest/profitable loan types, customer segments, credit score usefulness, loan size, interest rate, utilization, one surprising finding and one recommendation. Include at least five numerical findings and your bar, line and scatter charts.

# %%
# Write your code here
